# %%
import numpy as np

# %%
import pandas as pd

# %%
from sklearn.model_selection import train_test_split
from sklearn import tree

# %%
df = pd.read_csv('breast-cancer.csv')
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    ...  texture_worst  perimeter_worst  area_worst  smoothness_worst  \
# 0  ...          17.33           184.60      2019.0            0.1622
# 1  ...          23.41           158.80      1956.0            0.1238
# 2  ...          25.53           152.50      1709.0            0.1444
# 3  ...          26.50            98.87       567.7            0.2098
# 4  ...          16.67           152.20      1575.0            0.1374
#
#    compactness_worst  concavity_worst  concave points_worst  symmetry_worst  \
# 0             0.6656           0.7119                0.2654          0.4601
# 1             0.1866           0.2416                0.1860          0.2750
# 2             0.4245           0.4504                0.2430          0.3613
# 3             0.8663           0.6869                0.2575          0.6638
# 4             0.2050           0.4000                0.1625          0.2364
#
#    fractal_dimension_worst  Unnamed: 32
# 0                  0.11890          NaN
# 1                  0.08902          NaN
# 2                  0.08758          NaN
# 3                  0.17300          NaN
# 4                  0.07678          NaN
#
# [5 rows x 33 columns]

# %%
train_data, test_data, train_label, test_label = train_test_split(
    df[set(df.columns)-{'diagnosis', 'id', 'Unnamed: 32'}], 
    df.diagnosis, 
    test_size=0.4, 
    random_state=1)

# %%
train_data
# Out:
#      concave points_mean  symmetry_mean  fractal_dimension_se  concavity_mean  \
# 164             0.097020         0.1801              0.003740         0.13240
# 13              0.053640         0.1847              0.003002         0.09938
# 430             0.097110         0.2041              0.005784         0.27330
# 61              0.009259         0.1828              0.003048         0.03000
# 427             0.014040         0.2016              0.002690         0.03614
# ..                   ...            ...                   ...             ...
# 129             0.114900         0.2202              0.003224         0.25450
# 144             0.007875         0.1399              0.002360         0.02251
# 72              0.079440         0.1927              0.006299         0.16920
# 235             0.018960         0.1517              0.002925         0.01462
# 37              0.029230         0.1467              0.001777         0.02562
#
#      texture_mean  concave points_se  fractal_dimension_mean  texture_se  \
# 164         22.04           0.016230                 0.05553      0.8561
# 13          23.95           0.019920                 0.05338      1.0780
# 430         22.53           0.022340                 0.06898      0.8749
# 61          20.98           0.009259                 0.06757      2.0670
# 427         21.98           0.010450                 0.05977      1.6210
# ..            ...                ...                     ...         ...
# 129         25.12           0.010430                 0.06113      1.1990
# 144         14.97           0.005612                 0.05688      1.2390
# 72          24.52           0.011270                 0.06487      1.0410
# 235         21.25           0.010040                 0.05835      1.5030
# 37          18.42           0.011640                 0.05863      2.3420
#
#      concavity_worst  concave points_worst  ...  smoothness_worst  area_worst  \
# 164          0.39480               0.23460  ...           0.12280      2403.0
# 13           0.23220               0.11190  ...           0.11310       876.5
# 430          0.90190               0.24750  ...           0.14190       832.7
# 61           0.09001               0.02778  ...           0.16390       273.9
# 427          0.19270               0.07485  ...           0.13030       489.5
# ..               ...                   ...  ...               ...         ...
# 129          0.56730               0.17320  ...           0.12750      1589.0
# 144          0.09755               0.03413  ...           0.10760       441.2
# 72           0.65660               0.18990  ...           0.15850      1681.0
# 235          0.06231               0.07963  ...           0.12870       715.5
# 37           0.04833               0.05013  ...           0.09701       545.9
#
#      smoothness_mean  symmetry_se  radius_se  perimeter_mean  radius_mean  \
# 164          0.08439      0.01956     0.6642          152.10       23.270
# 13           0.08401      0.02981     0.4033          103.70       15.850
# 430          0.09947      0.01499     0.2530          102.10       14.900
# 61           0.12430      0.03357     0.3582           54.66        8.598
# 427          0.08801      0.01844     0.3077           68.79       10.800
# ..               ...          ...        ...             ...          ...
# 129          0.10150      0.01578     0.4953          130.40       19.790
# 144          0.07793      0.01671     0.2525           68.26       10.750
# 72           0.10710      0.01527     0.5907          114.20       17.200
# 235          0.09070      0.01263     0.2589           89.79       14.030
# 37           0.08983      0.02671     0.1839           82.61       13.030
#
#      texture_worst  compactness_worst  smoothness_se
# 164          28.22            0.35830       0.004910
# 13           27.66            0.19240       0.009769
# 430          27.57            0.70900       0.006965
# 61           27.04            0.16980       0.011930
# 427          32.04            0.16960       0.006543
# ..             ...                ...            ...
# 129          33.58            0.38610       0.005033
# 144          20.72            0.12230       0.006547
# 72           33.82            0.73940       0.005820
# 235          30.28            0.15130       0.007389
# 37           22.81            0.04619       0.004352
#
# [341 rows x 30 columns]

# %%
model = tree.DecisionTreeClassifier()

# %%
model = model.fit(train_data, train_label)

# %%
model.score(train_data, train_label)
# Out:
# 1.0

# %%
model.score(test_data, test_label)
# Out:
# 0.9210526315789473

# %%
tree.export_graphviz(model, out_file="output.dot")

# %%
# !dot -Tpng output.dot -o output.png
